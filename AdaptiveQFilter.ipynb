# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.array([1, 2, 3, 1, 5, 6, 3, 4, 2, 7])
plt.plot(a)

# %%
changes = 0
direction = 0
for i in range(1, len(a)):
    dir_n = np.sign(a[i] - a[i-1])
    if dir_n != direction:
        changes+=1
        direction = dir_n

# %%
changes
# Out:
# 7

# %%
np.count_nonzero(np.diff(np.sign(np.diff(a))))
# Out:
# 6

# %%
dt = 0.1
t = np.arange(0, 100, dt)
# Define a model track
Fs = 44100
n = np.random.normal(0,1,len(t))
d = 10*np.sin(2**np.pi*Fs*t)
x = d+10*n

# %%
plt.plot(x)

# %%
s = 0
den = 0
for i in range(len(d)):
    if n[i] != 0 and d[i] != 0:
        den = den+1
        s = s + 20*np.log10(np.abs(d[i]/10*n[i]))

s = s/den

# %%
noisy_10dB_path =
# Out:
# -11.535083334016782
